# %%
# Author: Tim Head <betatim@gmail.com>
#
# License: BSD 3 clause

import numpy as np
import pandas as pd
np.random.seed(10)

import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (RandomTreesEmbedding, RandomForestClassifier,
                              GradientBoostingClassifier)
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve
from sklearn.pipeline import make_pipeline

from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier

# %%
#open the locally saved csv
df = pd.read_csv('C:/Users/595217/general-assembly/project-final/data/mgm.csv', usecols=['description', 'jobtype', 'usetype'])

# %%
X = df['description']
y = df['usetype']
z = df['jobtype']

# %%
y = y.map({'Commercial': 0, 'Mixed Occupancy': 1, 'Residential': 2})
z = z.map({'New': 0, 'Existing': 1, 'Alteration': 2, 'Repair': 3, 'Other': 4, 'Addition': 5})

# %%
y_bin = label_binarize(y, classes=[0,1,2])
n_y_bin_classes = y_bin.shape[1]
z_bin = label_binarize(z, classes=[0,1,2,3,4,5])
n_z_bin_classes = z_bin.shape[1]

# %%
# create the BOW representation
bow_transform = text.CountVectorizer(min_df=0, stop_words="english")
X_bow = bow_transform.fit_transform(X)
len(bow_transform.vocabulary_)
# Out:
# 8943

# %%
#create tf-idf representation using the bow matrix
tfidf_trfm = text.TfidfTransformer(norm=None)
X_tfidf = tfidf_trfm.fit_transform(X_bow)
X_tfidf.shape
# Out:
# (17669, 8943)

# %%
n_estimator = 10

# %%
X_train, X_test, y_train, y_test, z_train, z_test = train_test_split(X_tfidf, y_bin, z_bin, test_size=0.50)

# %%
X_train, X_train_lr, y_train, y_train_lr, z_train, z_train_lr = train_test_split(X_train, y_train, z_train, test_size=0.50)

# %%
X_train.shape
# Out:
# (4417, 8943)

# %%
y_train.shape
# Out:
# (4417, 3)

# %%
X_train_lr.shape
# Out:
# (4417, 8943)

# %%
y_train_lr.shape
# Out:
# (4417, 3)

# %%
from sklearn.feature_extraction import text

# %%
n_estimator = 10
rf = RandomForestClassifier(max_depth=3, n_estimators=n_estimator)
rf_enc = OneHotEncoder()
rf_lm = OneVsRestClassifier(LogisticRegression())
rf.fit(X_train, y_train)
rf_enc.fit(rf.apply(X_train))
rf_lm.fit(rf_enc.transform(rf.apply(X_train_lr)), y_train_lr)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#           n_jobs=1)

# %%
y_pred_rf_lm = rf_lm.predict_proba(rf_enc.transform(rf.apply(X_test)))[:, 1]
fpr_rf_lm, tpr_rf_lm, _ = roc_curve(y_test, y_pred_rf_lm)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-553854666f5d> in <module>()
#       1 y_pred_rf_lm = rf_lm.predict_proba(rf_enc.transform(rf.apply(X_test)))[:, 1]
# ----> 2 fpr_rf_lm, tpr_rf_lm, _ = roc_curve(y_test, y_pred_rf_lm)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     532     """
#     533     fps, tps, thresholds = _binary_clf_curve(
# --> 534         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     535
#     536     # Attempt to drop thresholds corresponding to points in between and
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     316     if not (y_type == "binary" or
# ...

# %%
from sklearn.svm import SVC
from sklearn import svm
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier

NUM_TRIALS = 30

# Set up possible values of parameters to optimize over
p_grid = {"C": [1, 10, 100],
          "gamma": [.01, .1]}

svm = SVC(kernel="rbf")
clf = SVC()
classifier = OneVsRestClassifier(svm.SVC(kernel='linear', probability=True))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-b3c856b236a3> in <module>()
#      12
#      13 clf = SVC()
# ---> 14 classifier = OneVsRestClassifier(svm.SVC(kernel='linear', param_grid=p_grid, probability=True))
#
# TypeError: __init__() got an unexpected keyword argument 'param_grid'

# %%
# Loop for each trial
for i in range(NUM_TRIALS):

    # Choose cross-validation techniques for the inner and outer loops,
    # independently of the dataset.
    # E.g "LabelKFold", "LeaveOneOut", "LeaveOneLabelOut", etc.
    inner_cv = KFold(n_splits=4, shuffle=True, random_state=i)
    outer_cv = KFold(n_splits=4, shuffle=True, random_state=i)

#     # Non_nested parameter search and scoring
#     clf = GridSearchCV(estimator=classifier, cv=inner_cv, param_grid=p_grid)
#     clf.fit(X_train_tfidf, y_train)
#     non_nested_scores[i] = clf.best_score_

    # Nested CV with parameter optimization
    nested_score = cross_val_score(clf, X=X_train_tfidf, y=y_train, cv=outer_cv)
    nested_scores[i] = nested_score.mean()

score_difference = non_nested_scores - nested_scores

print("Average difference of {0:6f} with std. dev. of {1:6f}."
      .format(score_difference.mean(), score_difference.std()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-63d4eb860790> in <module>()
#      14
#      15     # Nested CV with parameter optimization
# ---> 16     nested_score = cross_val_score(clf, X=X_train_tfidf, y=y_train, cv=outer_cv)
#      17     nested_scores[i] = nested_score.mean()
#      18
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#     340                                 n_jobs=n_jobs, verbose=verbose,
#     341                                 fit_params=fit_params,
# --> 342                                 pre_dispatch=pre_dispatch)
#     343     return cv_results['test_score']
#     344
#
# ...

# %%
# Unsupervised transformation based on totally random trees
rt = RandomTreesEmbedding(max_depth=3, n_estimators=n_estimator,
    random_state=0)

rt_lm = LogisticRegression()
pipeline = make_pipeline(OneVsRestClassifier(rt, rt_lm))
pipeline.fit(X_train_lr_tfidf, y_train)
y_pred_rt = pipeline.predict_proba(X_test_lr_tfidf)[:, 1]
fpr_rt_lm, tpr_rt_lm, _ = roc_curve(y_test, y_pred_rt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-e7b960364867> in <module>()
#       5 rt_lm = LogisticRegression()
#       6 pipeline = make_pipeline(OneVsRestClassifier(rt, rt_lm))
# ----> 7 pipeline.fit(X_train_lr_tfidf, y_train)
#       8 y_pred_rt = pipeline.predict_proba(X_test_lr_tfidf)[:, 1]
#       9 fpr_rt_lm, tpr_rt_lm, _ = roc_curve(y_test, y_pred_rt)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     248         Xt, fit_params = self._fit(X, y, **fit_params)
#     249         if self._final_estimator is not None:
# --> 250             self._final_estimator.fit(Xt, y, **fit_params)
#     251         return self
#     252
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\multiclass.py in fit(self, X, y)
# ...

# %%
# Supervised transformation based on random forests
rf = RandomForestClassifier(max_depth=3, n_estimators=n_estimator)
rf_enc = OneHotEncoder()
rf_lm = LogisticRegression()
rf.fit(X_train_tfidf, y_train)
rf_enc.fit(rf.apply(X_train_tfidf))
rf_lm.fit(rf_enc.transform(rf.apply(X_train_lr)), y_train_lr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-bff3eaf56142> in <module>()
#       5 rf.fit(X_train_tfidf, y_train)
#       6 rf_enc.fit(rf.apply(X_train_tfidf))
# ----> 7 rf_lm.fit(rf_enc.transform(rf.apply(X_train_lr)), y_train_lr)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py in apply(self, X)
#     174             return the index of the leaf x ends up in.
#     175         """
# --> 176         X = self._validate_X_predict(X)
#     177         results = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     178                            backend="threading")(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _validate_X_predict(self, X)
#     355                                  "call `fit` before exploiting the model.")
#     356
# ...

# %%
y_pred_rf_lm = rf_lm.predict_proba(rf_enc.transform(rf.apply(X_test)))[:, 1]
fpr_rf_lm, tpr_rf_lm, _ = roc_curve(y_test, y_pred_rf_lm)

grd = GradientBoostingClassifier(n_estimators=n_estimator)
grd_enc = OneHotEncoder()
grd_lm = LogisticRegression()
grd.fit(X_train, y_train)
grd_enc.fit(grd.apply(X_train)[:, :, 0])
grd_lm.fit(grd_enc.transform(grd.apply(X_train_lr)[:, :, 0]), y_train_lr)

y_pred_grd_lm = grd_lm.predict_proba(
    grd_enc.transform(grd.apply(X_test)[:, :, 0]))[:, 1]
fpr_grd_lm, tpr_grd_lm, _ = roc_curve(y_test, y_pred_grd_lm)


# The gradient boosted model by itself
y_pred_grd = grd.predict_proba(X_test)[:, 1]
fpr_grd, tpr_grd, _ = roc_curve(y_test, y_pred_grd)


# The random forest model by itself
y_pred_rf = rf.predict_proba(X_test)[:, 1]
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_pred_rf)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-762c5c46ceff> in <module>()
#       5 rt_lm = LogisticRegression()
#       6 pipeline = make_pipeline(rt, rt_lm)
# ----> 7 pipeline.fit(X_train, y_train)
#       8 y_pred_rt = pipeline.predict_proba(X_test)[:, 1]
#       9 fpr_rt_lm, tpr_rt_lm, _ = roc_curve(y_test, y_pred_rt)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     246             This estimator
#     247         """
# --> 248         Xt, fit_params = self._fit(X, y, **fit_params)
#     249         if self._final_estimator is not None:
#     250             self._final_estimator.fit(Xt, y, **fit_params)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\pipeline.py in _fit(self, X, y, **fit_params)
# ...

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rt_lm, tpr_rt_lm, label='RT + LR')
plt.plot(fpr_rf, tpr_rf, label='RF')
plt.plot(fpr_rf_lm, tpr_rf_lm, label='RF + LR')
plt.plot(fpr_grd, tpr_grd, label='GBT')
plt.plot(fpr_grd_lm, tpr_grd_lm, label='GBT + LR')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
plt.figure(2)
plt.xlim(0, 0.2)
plt.ylim(0.8, 1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_rt_lm, tpr_rt_lm, label='RT + LR')
plt.plot(fpr_rf, tpr_rf, label='RF')
plt.plot(fpr_rf_lm, tpr_rf_lm, label='RF + LR')
plt.plot(fpr_grd, tpr_grd, label='GBT')
plt.plot(fpr_grd_lm, tpr_grd_lm, label='GBT + LR')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve (zoomed in at top left)')
plt.legend(loc='best')
plt.show()
